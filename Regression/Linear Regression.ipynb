# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
file_path = 'file/student-mat.csv' 
df=pd.read_csv(file_path,sep=';')
df.head(3)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2  G3
# 0      4        3      4     1     1      3        6  5  6   6
# 1      5        3      3     1     1      3        4  5  5   6
# 2      4        3      2     2     3      3       10  7  8  10
#
# [3 rows x 33 columns]

# %%
df=df[['age','freetime','absences','goout','G1','G2','G3']]
df.head(3)
# Out:
#    age  freetime  absences  goout  G1  G2  G3
# 0   18         3         6      4   5   6   6
# 1   17         3         4      3   5   5   6
# 2   15         3        10      2   7   8  10

# %%
predication = 'G3'
x = np.array(df.drop([predication], axis=1))
y = np.array(df[predication])

# %%
x_train , x_test ,  y_train, y_test = train_test_split(x , y, test_size =0.1)
model=linear_model.LinearRegression()
model.fit(x_train,y_train)
score = model.score(x_test,y_test)
print(score)
# Out:
# 0.9113128812035868

# %%
model.coef_
# Out:
# array([-0.20085657,  0.10690205,  0.04309354,  0.06513526,  0.1650663 ,
#         0.96633022])

# %%
model.intercept_
# Out:
# np.float64(0.8187160009472532)

# %%
y = a1x + a2p + a3k +... +b

# %%
x_test[0]
# Out:
# array([16,  3,  0,  3, 11, 10])

# %%
y= -0.20085657 * 16 + 0.10690205 * 3 + 0.04309354*0 + 0.06513526 * 3 + 0.1650663 * 11 + 0.96633022 * 10 + 0.8187160009472532
print(y)
# Out:
# 9.600154310947254

# %%
model.predict([x_test[0]])
# Out:
# array([9.60015426])

# %%
predictions = model.predict(x_test)
plt.figure(figsize=(15, 5))
plt.plot(predictions, label='Predictions')
plt.plot(y_test, label='Real Values')
plt.legend()
plt.grid()
plt.show()

# %%
for i in range(len(predications)):
    print(f'predications:{predications[i]}\t real{y_test[i]}')
# Out:
# predications:14.013681712822882	 real10
# predications:16.197203295922186	 real11
# predications:0.05132025551285979	 real10
# predications:12.865745788868589	 real10
# predications:7.517814178732283	 real8
# predications:12.903954660340045	 real15
# predications:6.062718003071009	 real13
# predications:13.815745729379865	 real15
# predications:7.445330638218982	 real15
# predications:6.884547350856952	 real15
# predications:17.337370276196616	 real12
# predications:11.113918452317337	 real8
# predications:9.668466568192093	 real13
# predications:16.178679912643048	 real10
# predications:4.0954508678835735	 real17
# predications:16.482244696960286	 real15
# predications:7.79506237775997	 real15
# predications:9.329120802129264	 real12
# predications:-1.1373731423066609	 real10
# predications:14.829880553675805	 real8
# predications:6.985318028462212	 real11
# predications:7.9011855504234845	 real0
# predications:9.994133289323253	 real6
# predications:6.458438998867567	 real15
# ...
